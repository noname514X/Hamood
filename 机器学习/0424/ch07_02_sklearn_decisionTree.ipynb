# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# 1. 读取数据
df = pd.read_csv(r'd:\data\winequality-white.csv',sep=';')

# 2. 添加质量标签列（quality_label）
def quality_to_label(q):
    if q <= 5:
        return 'low'
    elif q <= 7:
        return 'medium'
    else:
        return 'high'

df['quality_label'] = df['quality'].apply(quality_to_label)

# 3. 准备特征和标签
X = df.drop(['quality', 'quality_label'], axis=1)  # 去除原始 quality 和标签列
y = df['quality_label']

# 4. 拆分训练集和测试集
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 from sklearn.tree import DecisionTreeClassifier, plot_tree
#       3 from sklearn.model_selection import train_test_split
#
# File /opt/anaconda3/envs/MCM_2025/lib/python3.12/site-packages/pandas/__init__.py:14
#      12 for _dependency in _hard_dependencies:
#      13     try:
# ---> 14         __import__(_dependency)
#      15     except ImportError as _e:  # pragma: no cover
#      16         _missing_dependencies.append(f"{_dependency}: {_e}")
#
# File /opt/anaconda3/envs/MCM_2025/lib/python3.12/site-packages/numpy/__init__.py:114
#     111 from . import _distributor_init
#     113 try:
# --> 114     from numpy.__config__ import show_config
#     115 except ImportError as e:
#     116     msg = """Error importing numpy: you should not try to import numpy from
# ...

# %%
# 5. 创建决策树模型
clf = 

# 6. 训练模型
clf.

# 7. 预测和评估
y_pred = 
accuracy = 

print(f"\n模型准确率: {accuracy:.2f}")
print("决策树深度:", clf.get_depth())

# 8. 可视化决策树
plt.figure(figsize=(20, 12))
plot_tree(
    clf, 
    filled=True, 
    feature_names=X.columns, 
    class_names=clf.classes_, 
    rounded=True
)
plt.title("决策树 - 葡萄酒质量等级分类")
plt.show()

# %%
# —— 测试集准确率（之前已经有了）——
y_pred_test = clf.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred_test)
print(f"\n测试集准确率: {test_accuracy:.2f}")

# —— 训练集准确率（新加的）——
y_pred_train = 
train_accuracy = 
print(f"训练集准确率: {train_accuracy:.2f}")
