# %% [markdown]
# # <font color = 'blue'>python条件语句与python函数 </font>

# %% [markdown]
# ## 1.上节课复习：字符串
#
# ## 2.Python的条件语句
#
# ### 2.1.if语句
#
# ### 2.2.if...else...
#
# ### 2.3.多重判断 if...elif...else
#
# ### 2.4.if 嵌套
#
# ## 3.Python的函数

# %% [markdown]
# ## <font color = 'red'>1.上节课复习：字符串 </font>

# %%
var1 = 'Hello World!'
var2 = "I love Python Coding"

# %%
#字符串的切片
print ("var1[0]:", var1[0])
print("var1[-1:]:",var1[-1:])
print("var1[:7]:",var1[:7])
print("var1[4:8]:",var1[4:8])
print("var2[0:12:2]:",var2[0:12:2])
print("var2[::-1]:",var2[::-1])
# Out:
# var1[0]: H
# var1[-1:]: !
# var1[:7]: Hello W
# var1[4:8]: o Wo
# var2[0:12:2]: Ilv yh
# var2[::-1]: gnidoC nohtyP evol I

# %%
#len ，len（str）返回字符串的长度（字符个数）空格也是字符
print(len(var2))
# Out:
# 20

# %%
#eval(str)，eval（str）可将字符串str当成有效的表达式并返回计算结果
print("12+3")
print(int('15'))
print(eval("12+3"))
print(int('12+3'))   #报错
# Out:
# 12+3
# 15
# 15
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-6a1d0d4cd7e2> in <module>
#       3 print(int('15'))
#       4 print(eval("12+3"))
# ----> 5 print(int('12+3'))   #报错
#
# ValueError: invalid literal for int() with base 10: '12+3'

# %%
#lower（str）转换大写字母为小写字母（相当于重新生成一个字符串）
print(var2.lower())
# Out:
# i love python coding

# %%
var2.

# %%
#upper（str）转换小写字母为大写字母（相当于重新生成一个字符串）与lower()刚好相反
print(var2.upper())
# Out:
# I LOVE PYTHON CODING

# %%
#title()每个单词的首字母大写
print(var2.title())
# Out:
# I Love Python Coding

# %%
#capitalize()首字母大写，其他小写
print(var2.capitalize())
# Out:
# I love python coding

# %%
#swapcase()转换字符串中的小写字母为大写，大写字母为小写
print(var2.swapcase())
# Out:
# i LOVE pYTHON cODING

# %%
#count（str[，start][，end]）返回字符串中str出现的次数，可以指定一个范围，默认从头到尾
str1 = "so that we like close close friends"
print(str1.count("close"))
print(str1.count("close", 20, len(str1)))
# Out:
# 2
# 1

# %%
#find（str[,strat][,end]）从左向右检测str字符串是否包含查找的字符串，可以指定范围，默认从头到尾，得到的是第一次出现的开始下标，没有返回-1
str2 = "so that we like close close friends"
print(str2.find("close"))
print(str2.find("man"))
# Out:
# 16
# -1

# %%
#ljust（width，filch）返回一个指定宽度的左对齐字符串，filch为填充字符，默认空格,
# rjust（width，filch）同理，为右对齐,
# center（width，filch）返回一个居中的指定字符串
# zfill（width）返回一个长度为width的字符串，原字符串右对齐，前面补0
str3 = "man"
print(str3.ljust(40, "*"))
print(str3.rjust(40, "*"))
print(str3.center(40, "*"))
print(str3.zfill(40))
# Out:
# man*************************************
# *************************************man
# ******************man*******************
# 0000000000000000000000000000000000000man

# %%
var2
# Out:
# 'I love Python Coding'

# %%
#split函数
var2.split(' ')
# Out:
# ['I', 'love', 'Python', 'Coding']

# %%
#replace函数
var3 = var2.replace(' ', '|') 
var3
# Out:
# 'I|love|Python|Coding'

# %%
var3.split('|')
# Out:
# ['I', 'love', 'Python', 'Coding']

# %%
type(var3.split('|') )
# Out:
# list

# %%
type(var3)
# Out:
# str

# %%
#lstrip()截取掉字符串左侧指定的字符，默认为空格，可以看出，写上截取参数后，空格就会被截取掉了
str4 = "             a good man!"
str5 = "*****a good man!"
print(str4.lstrip())
print(str5.lstrip("*"))
# Out:
# a good man!
# a good man!

# %% [markdown]
# ## <font color = 'red'>2.Python的条件语句 </font>
#
# Python 中的 条件控制语句 (Conditional control statement) 是通过一条或者多条语句的执行结果（True 或者 False），来决定执行的代码逻辑 。
#
# 关键词：它包含 if 、elif 、else 关键字， Python 中是不存在 else if 的写法，只存在 elif 这种写法。
#
# 冒号很重要：每句判断语句使用冒号 - : 结尾，使用 缩进 划分语句块，相同缩进数的语句组成一个语句块。
#
# 3种条件控制语句：if 、if - else 、if - elif (多个elif) - else

# %% [markdown]
# ### 2.1.if语句
# if 语句，仅有一个判断条件，如果条件成立（为 True），则执行判断语句后带缩进的代码逻辑，否则不执行。

# %%
a = 1
if a==1:   #注意冒号
    print('恭喜你，选中邓老师的《金融科技基础》课程')
# Out:
# 恭喜你，选中邓老师的《金融科技基础》课程

# %% [markdown]
# #### 2.1.1 简单版：网吧上网
# 需求分析：如果用户年龄大于等于18岁，即成年，输出"已经成年，可以上网"。

# %%
age = 20
if age >= 18:
    print('已经成年，可以上网')
# Out:
# 已经成年，可以上网

# %% [markdown]
# #### 2.1.2 进阶版：网吧上网
# 新增需求：用户可以输出自己的年龄，然后系统进行判断是否成年，成年则输出"您的年龄是’用户输入的年龄’，已经成年，可以上网"。

# %%
# input接受用户输入的数据是字符串类型，条件是age和整型18做判断，所以这里要int转换数据类型
age = int(input('请输入您的年龄：'))

if age >= 18:
    print(f'您的年龄是{age}岁,已经成年，可以上网')  #f-  字符串的格式化  format
# Out:
# 请输入您的年龄：19
# 您的年龄是19岁,已经成年，可以上网

# %% [markdown]
# ### 2.2 if...else...
# 作用：条件成立执行if下方的代码; 条件不成立执行else下方的代码。

# %%
# 判断同花顺是否在某个股票池内

# 股票列表
stock = ['同花顺','工商银行','五粮液']
# 判断语句
if '同花顺' in stock:
    
    
    # 满足条件输出
    print('同花顺在股票池内')
# 判断语句
else:
    # 不满足条件输出
    print('同花顺不在股票池内')
# Out:
# 同花顺在股票池内

# %% [markdown]
# #### 2.2.1实用版：网吧上网

# %%
age = int(input('请输入您的年龄：'))

if age >= 18:
    print(f'您的年龄是{age},已经成年，可以上网')
else:
    print(f'您的年龄是{age},未成年，请自行回家写作业')
    print('系统关闭')
# Out:
# 请输入您的年龄：20
# 您的年龄是20,已经成年，可以上网

# %% [markdown]
# ### 2.3.多重判断 if...elif...else
#
# 　对于多条件，要写成elif，标准格式为：<br><br>
# 　　　if 条件1:<br>
# 　　　　执行语句1<br>
# 　　　elif 条件2:<br>
# 　　　　执行语句2<br>
# 　　　else:<br>
# 　　　　执行语句3<br><br>
# 　　注意if…elif…else三个是并列的，不能有缩进：<br>

# %% [markdown]
# #### 2.3.1实例:判断某只股票RSI指标强弱

# %%
# age = int(input('请输入您的年龄：'))

# if age >= 18:
#     print(f'您的年龄是{age},已经成年，可以上网')
# else:
#     print(f'您的年龄是{age},未成年，请自行回家写作业')
#     print('系统关闭')
    
# 多行注释  ctrl+ /
'''
使用if条件，编成程序：判断某只股票RSI指标强弱。
多行注释
'''

# 输入某只股票的RSI值【0-100】
stockRSI = 80

# 判断<20
if stockRSI<=20:
    # 输出
    print('该股票目前弱，不建议买入')
# 再次判断 20-50
elif stockRSI > 20 and stockRSI < 50:      #           20 <stockRSI< 50
    # 输出
    print('该股票目前较弱，建议观望')
# 再次判断
elif stockRSI == 50:
    # 输出
    print('该股票目前方向不明确，建议观望')
# 再次50-70
elif stockRSI > 50 and stockRSI < 70:
    #输出
    print('该股票目前较好，建议买一点')
# 再次判断 >70
elif stockRSI>=70:
    # 输出
    print('该股票目前好，建议买入')
# Out:
# 该股票目前好，建议买入

# %% [markdown]
# #### 2.3.2实例:工龄判断

# %%
age = int(input('请输入您的年龄：'))
if age < 18:
    print(f'您的年龄是{age},童工一枚')
elif (age >= 18) and (age <= 60):
    print(f'您的年龄是{age},合法工龄')
else:
    print(f'您的年龄是{age},可以退休')
# Out:
# 请输入您的年龄：70
# 您的年龄是70,可以退休

# %% [markdown]
# ### 2.4.if嵌套
# if 条件1：
#   条件1成立执行的代码
#     条件1成立执行的代码
#
#     if 条件2：
#       条件2成立执行的代码
#         条件2成立执行的代码

# %% [markdown]
# #### 2.4.1实例:坐公交-判断是否能上车

# %%
"""
  1. 如果有钱，则可以上车
    2. 上车后，如果有空座，可以坐下
    上车后，如果没有空座，则站着等空座位
  如果没钱，不能上车
"""
# 假设用 money = 1 表示有钱, money = 0表示没有钱
money = 0
if money == 1:
    print('土豪，不差钱，顺利上车')
else:
    print('没钱，不能上车，追着公交车跑')
# Out:
# 没钱，不能上车，追着公交车跑

# %% [markdown]
# #### 2.4.2实例:坐公交-判断是否能坐下

# %%
"""
  1. 如果有钱，则可以上车
     1.1. 上车后，如果有空座，可以坐下
        上车后，如果没有空座，则站着等空座位
  2.如果没钱，不能上车
"""
# 假设用 money = 1 表示有钱, money = 0表示没有钱; seat = 1 表示有空座，seat = 0 表示没有空座
money = 1
seat = 0
if money == 1:
    print('土豪，不差钱，顺利上车')
    if seat == 1:
        print('有空座，可以坐下')
    else:
        print('没有空座，站等')
else:
    print('没钱，不能上车，追着公交车跑')
# Out:
# 土豪，不差钱，顺利上车
# 没有空座，站等

# %%
#练习1：
money = int(input("请输入你钱包的余额:"))
if money > 3000:
    if money > 5000:
        print("买一台PS5游戏机")
    else:
        print("买台switch游戏掌机")
else:
    print("回家看书学习")
# Out:
# 请输入你钱包的余额:6000
# 买一台PS5游戏机

# %%
#练习2：
"""
接收用户输入一个分数,判断该分数属于哪一个等级
A：90-100
B：80-89
C：70-79
D：70以下
"""
score = int(input(">>>"))
if  90<=score<=100:    #score>=90 and score<=100
    print("A")
elif 80<=score<=89:
    print("B")
elif 70<=score<=79:
    print("C")
else:
    print("D")
# Out:
# >>>85
# B

# %%
#练习3：猜拳游戏
"""
提示：
1.   0-石头，1-剪刀，2-布
2.   出拳
玩家输入出拳
电脑随机出拳

3.   判断输赢
玩家获胜
平局
电脑获胜
"""

# 导入random模块
import random
# 计算电脑出拳的随机数字

player = int(input('请出拳：0-石头，1-剪刀，2-布：'))
computer = random.randint(0, 2)
print(computer)

# 玩家胜利 p0:c1 或 p1:c2 或 p2:c0
if (player == 0 and computer == 1) or (player == 1 and computer == 2) or (player == 2 and computer == 0):
    print('玩家获胜')

# 平局：玩家 == 电脑
elif player == computer:
    print('平局')
else:
    print('电脑获胜')
# Out:
# 请出拳：0-石头，1-剪刀，2-布：2
# 1
# 电脑获胜

# %%
#练习4：猜拳游戏进阶版
"""
石头剪刀布游戏
玩家VS电脑
站在玩家的角度，分析胜利、失败、平局
0-石头，1-剪刀，2-布
"""
# 导入随机数模块
import random

import sys

print("-----欢迎来到人机对战小游戏-----")
name = input("请输入您的游戏名：")
while True:
    stats = input("欢迎“%s”来到本游戏，开始游戏输入Y，退出游戏输入N，请您输入：" % name)
    if stats == "Y" or stats == "y":
        print("游戏开始……")
        print("石头输入0、剪刀输入1、布输入2")
        break
    elif stats == "N" or stats == "n":
        print("游戏结束……")
        sys.exit(0)
    else:
        print("请按照要求重新输入！")
print("-------------加载中-------------")

def Game(user, comp):
    if (user== 0 and comp== 1) or (user== 1 and comp== 2) or (user== 2 and comp== 0):
        print("机器输入%d，您赢了！" % comp)
    elif user == comp:
        print("机器输入%d，平局了！" % comp)
    else:
        print("机器输入%d，您输了！" % comp)
    res = input("重新游戏请输入X，退出游戏按任意键")
    if res == "X" or res == "x":
        return
    else:
        sys.exit(0)


while True:
    user = int(input("请您出拳，输入相应数字！"))
    if user == 0 or user == 1 or user == 2:
        comp = random.randint(0, 2)
        Game(user, comp)
    else:
        print("输入数字有误，请确认后，重新输入！")
# Out:
# -----欢迎来到人机对战小游戏-----
# 游戏开始……
# 石头输入0、剪刀输入1、布输入2
# -------------加载中-------------
# 机器输入2，平局了！
# 机器输入0，您输了！
# 机器输入0，您输了！
# 机器输入1，平局了！
# 机器输入2，您赢了！
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /opt/anaconda3/envs/MCM_2025/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3557: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
#练习5：判断三角形的类型
a = int(input(">>>"))
b = int(input(">>>"))
c = int(input(">>>"))
if 0<a<180 and 0<b<180 and 0<c<180 and a+b+c==180: 
    if a>90 or b>90 or c>90: 
        if a==b or a==c or b==c:
            print("钝角等腰三角形")
        else:
            print('一般钝角三角形') 

    elif a==90 or b==90 or c==90: 
        if a==b or a==c or b==c:
            print("等腰直角三角形")
        else:
            print("一般直角三角形")
    else: 
        if a==b==c:
            print("等边三角形")
        elif a==b or a==c or b==c:
            print("锐角等腰三角形")
        else:
            print("锐角三角形")
else:
    print("您输入的不是不是三角形；")
# Out:
# >>>60
# >>>70
# >>>50
# 锐角三角形

# %% [markdown]
# ### <font color = 'red'>## 3.Python的函数</font>
#     函数是组织好的，可重复使用的，用来实现单一，或相关联功能的代码段。函数能提高应用的模块性，和代码的重复利用率。<br><br>
# #### 3.1 调用函数<br>
# 　　Python内置了很多有用的函数，我们可以直接调用。<br>
# 　　要调用一个函数，需要知道函数的名称和参数，比如求绝对值的函数abs，只有一个参数。<br>
# 　　调用abs函数：<br>

# %%
abs(-100)
# Out:
# 100

# %%
abs(1, 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-6c188a838f2b> in <module>
# ----> 1 abs(1, 2)
#
# TypeError: abs() takes exactly one argument (2 given)

# %%
abs('a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-f2001f88707b> in <module>
# ----> 1 abs('a')
#
# TypeError: bad operand type for abs(): 'str'

# %% [markdown]
# #### 3.2 定义函数
# 　　在Python中，定义一个函数要使用def语句，依次写出函数名、括号、括号中的参数和冒号:，然后，在缩进块中编写函数体，函数的返回值用return语句返回。<br>
# 　　我们以自定义一个求绝对值的abs_my函数为例：<br>

# %%
def abs_my(x):
    if x >= 0:
        return x
    else:
        return -x

# %%
abs_my(-100)
# Out:
# 100

# %%
abs_my(35)
# Out:
# 35

# %%
def subtract_bc(a,b,c):
    result = a - b*c
#     print ('Parameter a equals', a)
#     print ('Parameter b equals', b)
#     print ('Parameter c equals', c)
    print ('Parameter result equals:',result)
    return result

# %%
subtract_bc(10,3,2)
# Out:
# Parameter result equals: 4
# 4

# %%
result=25

# %%
print ('Parameter result equals',result)
# Out:
# Parameter result equals 25

# %%
subtract_bc(b=3,a=10,c=2)
# Out:
# Parameter result equals: 4
# 4

# %% [markdown]
# 　　请注意，函数体内部的语句在执行时，一旦执行到return时，函数就执行完毕，并将结果返回。因此，函数内部通过条件判断和循环可以实现非常复杂的逻辑。<br>
# 　　如果没有return语句，函数执行完毕后也会返回结果，只是结果为None。<br>
# 　　return None可以简写为return。<br><br>

# %% [markdown]
# ### 3.3函数的参数
# 　　定义函数的时候，我们把参数的名字和位置确定下来，函数的接口定义就完成了。对于函数的调用者来说，只需要知道如何传递正确的参数，以及函数将返回什么样的值就够了，函数内部的复杂逻辑被封装起来，调用者无需了解。<br>
# 　　Python的函数定义非常简单，但灵活度却非常大。除了正常定义的必选参数外，还可以使用默认参数、可变参数和关键字参数，使得函数定义出来的接口，不但能处理复杂的参数，还可以简化调用者的代码。<br><br>
# **3.3.1 默认参数**<br>
# 　　我们仍以具体的例子来说明如何定义函数的默认参数。先写一个计算y的平方的函数：<br>

# %%
def power(y):
    return y * y

# %% [markdown]
# 当我们调用 power 函数时，必须传入有且仅有的一个参数 y：

# %%
power(5)
# Out:
# 25

# %%
power(0)
# Out:
# 0

# %% [markdown]
# 现在，如果我们要计算 y^3 怎么办？可以再定义一个power3函数，但是如果要计算y^4、y^5……怎么办？我们不可能定义无限多个函数。
# 　　函数中再添加一个参数即可帮助我们搞定这个问题！

# %%
def power(y, t):
    d = 1
    while t > 0:       #while 只要正确，一直循环下去，第一次出现不正确，就跳出循环
        t = t - 1
        d = d * y
        #t = t - 1
    return d

# %% [markdown]
# 　　对于这个修改后的 power 函数，可以计算任意 n 次方：

# %%
power(5, 3)
# Out:
# 125

# %% [markdown]
# 但是，旧的调用代码失败了，原因是我们增加了一个参数，导致旧的代码无法正常调用：

# %%
power(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-4cd340f296c6> in <module>
# ----> 1 power(5)
#
# TypeError: power() missing 1 required positional argument: 't'

# %% [markdown]
# 这个时候，默认参数就排上用场了。由于我们经常计算y的平方，所以，完全可以把第二个参数 n 的默认值设定为 2：

# %%
def power(y, t=2):
    d = 1
    while t > 0:
        t = t - 1
        d = d * y
    return d

# %%
power(10)
# Out:
# 100

# %%
power(5, 3)
# Out:
# 125

# %%
power(5, 4)
# Out:
# 625

# %%
power(3,5)
# Out:
# 243

# %%
power(5,t=4)
# Out:
# 625

# %%
power(4)
# Out:
# 16

# %% [markdown]
# 而对于 n > 2 的其他情况，就必须明确地传入 n，比如 power(5, 3)。<br>
# 　　从上面的例子可以看出，默认参数可以简化函数的调用。设置默认参数时，有几点要注意：<br><br>
# 　　　(1)、必选参数在前，默认参数在后，否则Python的解释器会报错。<br>
# 　　　(2)、如何设置默认参数。当函数有多个参数时，把经常改动的参数放前面，不经常改动的参数放后面。不经常改动的参数就可以作为默认参数。<br><br>
# 　　使用默认参数有什么好处？最大的好处是能降低调用函数的难度。<br><br>

# %%
power(t=4,5)
# Out:
#   File "<ipython-input-42-597a17afbf62>", line 1
#     power(t=4,5)
#               ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# **3.3.2可变参数**<br>
# 　　在Python函数中，还可以定义可变参数。顾名思义，可变参数就是传入的参数个数是可变的，可以是1个、2个到任意个，还可以是0个。<br>
# 　　我们以数学题为例子，给定一组数字a，b，c……，请计算 a+b+c+……。<br>
# 　　要定义出这个函数，我们必须确定输入的参数。由于参数个数不确定，我们首先想到可以把a，b，c……作为一个 list 或 tuple 传进来，这样，函数可以定义如下：<br>

# %%
def sum_my(n):
    d = 0
    for n in n:
        d = d + n 
    return d

# %% [markdown]
# 　　但是调用的时候，需要先组装出一个 list 或 tuple：

# %%
sum_my(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-ec03eaf2644e> in <module>
# ----> 1 sum_my(1,2,3)
#
# TypeError: sum_my() takes 1 positional argument but 3 were given

# %%
sum_my([1, 2, 3])
# Out:
# 6

# %%
sum_my((1, 3, 5, 7))
# Out:
# 16

# %% [markdown]
# 　如果利用可变参数，我们把函数的参数改为可变参数:

# %%
def sum_my(*n):
    d = 0
    for n in n:
        d = d + n 
    return d

# %% [markdown]
# 调用函数的方式可以简化成这样：

# %%
sum_my(1, 2, 3)
# Out:
# 6

# %%
sum_my(1, 3, 5, 7)
# Out:
# 16

# %% [markdown]
# 　　定义可变参数和定义 list 或 tuple 参数相比，仅仅在参数前面加了一个 * 号。在函数内部，参数 numbers 接收到的是一个 tuple，因此，函数代码完全不变。但是，调用该函数时，可以传入任意个参数，包括 0 个参数：

# %%
sum_my()
# Out:
# 0

# %% [markdown]
# 　　如果已经有一个 list 或者 tuple，要调用一个可变参数怎么办？ Python允许你在 list 或 tuple 前面加一个 * 号，把 list 或 tuple 的元素变成可变参数传进去,可以这样做：

# %%
number = [1, 2, 3]
sum_my(*number)
# Out:
# 6

# %%
number =(1, 2, 3)
sum_my(*number)
# Out:
# 6

# %% [markdown]
# 　　这种写法相当有用，而且很常见。<br><br>
# **3.3.3关键字参数**<br><br>
# 　　可变参数允许你传入 0 个或任意个参数，这些可变参数在函数调用时自动组装为一个 tuple。而关键字参数允许你传入 0 个或任意个含参数名的参数，这些关键字参数在函数内部自动组装为一个 dict。请看示例：<br>

# %%
def myclass(name, number, **other):
    print('name:', name, 'number:', number, 'other:', other)

# %% [markdown]
# 函数myclass除了必选参数 name 和 number 外，还接受关键字参数 other。在调用该函数时，可以只传入必选参数：

# %%
myclass('Lili',4001)
# Out:
# name: Lili number: 4001 other: {}

# %% [markdown]
# 　　也可以传入任意个数的关键字参数：

# %%
myclass('yunyun', 4012, gender='girl', age='23')
# Out:
# name: yunyun number: 4012 other: {'gender': 'girl', 'age': '23'}

# %% [markdown]
# 关键字参数有什么用？它可以扩展函数的功能。比如，在myclass函数里，我们保证能接收到name和age这两个参数，但是，如果调用者愿意提供更多的参数，我们也能收到。试想你正在做一个用户注册的功能，除了用户名和年龄是必填项外，其他都是可选项，利用关键字参数来定义这个函数就能满足注册的需求。<br><br>

# %% [markdown]
# **3.3.4 混合参数**<br><br>
# 　　在Python中定义函数，可以用必选参数、默认参数、可变参数和关键字参数，这4种参数都可以一起使用，或者只用其中某些，但是请注意，参数定义的顺序必须是：必选参数、默认参数、可变参数和关键字参数。<br>
# 　　比如定义一个函数，包含上述4种参数：<br>

# %%
def number(a, b=0, *c, **d):
    print('a =', a, 'b =', b, 'c =', c, 'd =', d)

# %% [markdown]
# 同学们在记忆时，可尝试对应四个选项，采用巧记的方式:a是a，b为0，c前一颗星，d前两颗星，a必须定义，b默认为0，c可多定义，d为小字典，可额外补充。<br>
# 　　在函数调用的时候，Python解释器自动按照参数位置和参数名把对应的参数传进去。<br>

# %%
number(1,3,3,3,5,(7,9),d=4,f=6)
# Out:
# a = 1 b = 3 c = (3, 3, 5, (7, 9)) d = {'d': 4, 'f': 6}

# %%
number(4,3,3,5,g=1,f=6)
# Out:
# a = 4 b = 3 c = (3, 5) d = {'g': 1, 'f': 6}

# %%
number(4,0,3,3,3,5,e=4,d=6)
# Out:
# a = 4 b = 0 c = (3, 3, 3, 5) d = {'e': 4, 'd': 6}

# %%
number(4,0,3,3,3,5,c=4,d=6)
# Out:
# a = 4 b = 0 c = (3, 3, 3, 5) d = {'c': 4, 'd': 6}

# %%
number(4,0,3,3,3,5,c=2,d=6)
# Out:
# a = 4 b = 0 c = (3, 3, 3, 5) d = {'c': 2, 'd': 6}

# %%
number(4,0,3,3,3,5,d=6)
# Out:
# a = 4 b = 0 c = (3, 3, 3, 5) d = {'d': 6}

# %%
number(4,0,c=(3,3,3,5),e=4,d=6)
# Out:
# a = 4 b = 0 c = () d = {'c': (3, 3, 3, 5), 'e': 4, 'd': 6}

# %%
number(4,f=3,c=(3,3,3,5),e=4,d=6)
# Out:
# a = 4 b = 0 c = () d = {'f': 3, 'c': (3, 3, 3, 5), 'e': 4, 'd': 6}

# %%
number(4,5,x=(1,3,3,3,5),e=4,d=6)
# Out:
# a = 4 b = 5 c = () d = {'x': (1, 3, 3, 3, 5), 'e': 4, 'd': 6}

# %%
number(4,3,3,3,5,c=2,e=4,d=6)
# Out:
# a = 4 b = 3 c = (3, 3, 5) d = {'c': 2, 'e': 4, 'd': 6}

# %%
number(4,4,e=4,c=(3,3,3,5),d=6)
# Out:
# a = 4 b = 4 c = () d = {'e': 4, 'c': (3, 3, 3, 5), 'd': 6}

# %%
def func7(*args, **kwargs):
    print(args, kwargs)

# %%
func7(10, 5, 89)
# Out:
# (10, 5, 89) {}

# %%
func7(a=90, b=9, c=90)
# Out:
# () {'a': 90, 'b': 9, 'c': 90}

# %%
def func7(*args, **kwargs):
    print(args, kwargs)
 
 
func7(10, 5, 89)
func7(a=90, b=9, c=90)
# Out:
# (10, 5, 89) {}
# () {'a': 90, 'b': 9, 'c': 90}
