# %% [markdown]
# ## <font color = 'red'>为什么学习python，能干什么</font>

# %%
import os
print(os.getcwd())  # 显示当前路径
# Out:
# /Users/ncc1031a/Documents/VSCode/FinancialTech/1_Python_basics

# %%
from IPython.display import Image
Image(url= "python与金融量化基础.png", 
      width=800, height=400)
# Out:
# <img src="python与金融量化基础.png" width="800" height="400"/>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# 设置随机数种子，确保每次生成的图像相同
np.random.seed(0)

# 生成一组数据，这里使用标准正态分布生成随机数
data = np.random.normal(0, 1, 1000)

# 绘制直方图
plt.hist(data, bins=30, density=True, alpha=0.6, color='g')

# 绘制标准正态分布曲线
x = np.linspace(-3, 3, 100)
p = norm.pdf(x, 0, 1)
plt.plot(x, p, 'r-', lw=2)

# 设置图像标题和坐标轴标签
plt.title('Standard Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Probability Density')

# 显示图像
plt.show()

# %%
import os
print(os.getcwd())  # 显示当前路径
# Out:
# /Users/ncc1031a/Documents/VSCode/FinancialTech/1_Python_basics

# %%
# pip show pip

# %% [markdown]
# ## <font color = 'red'>1. Python包的安装与升级</font>
# 1、显示pip版本
# pip show pip
#
# 2、升级pip命令
# python -m pip install --upgrade pip
#
# pip3 install --upgrade pip
#
# 3、安装包
# pip install SomePackage              # 最新版本
# pip install SomePackage==1.0.4       # 指定版本
# pip install 'SomePackage>=1.0.4'     # 最小版本
# python3 -m pip install XXX
#
# 4、升级包
# pip install --upgrade SomePackage
#
# 5、卸载包
# pip uninstall SomePackage
#
# 6、查看已经安装的包
# pip list
#
# 7、查看可以升级的包
# pip list -o
# pip 清华大学开源软件镜像站  例如，安装 Django：
# pip install -i https://pypi.tuna.tsinghua.edu.cn/simple Django

# %%
pip list
# Out:
# Package                 Version
# ----------------------- -----------
# absl-py                 2.1.0
# affine                  2.4.0
# appnope                 0.1.4
# asttokens               3.0.0
# attrs                   25.1.0
# Bottleneck              1.4.2
# Brotli                  1.0.9
# certifi                 2025.1.31
# charset-normalizer      3.3.2
# click                   8.1.8
# click-plugins           1.1.1
# cligj                   0.7.2
# comm                    0.2.2
# contextily              1.6.2
# contourpy               1.3.1
# cycler                  0.11.0
# cykhash                 2.0.1
# Cython                  3.0.11
# debugpy                 1.8.11
# decorator               5.2.1
# et-xmlfile              1.1.0
# exceptiongroup          1.2.2
# executing               2.1.0
# filelock                3.13.1
# fonttools               4.55.3
# geographiclib           2.0
# geojson                 3.2.0
# geopandas               1.0.1
# ...

# %% [markdown]
# ## <font color = 'red'>2. 在jupyter中如何编辑文本与编写代码转换</font>
#
# ### 命令模式
#
# - **Ctrl + Enter**：运行选的 Cell，运行完选择当前 Cell
# - **Shift + Enter**：运行选的 Cell，运行完选择下个 Cell
# - **Alt + Enter**：运行选的 Cell，运行在下面插入新的 Cell
# - **Esc + Y**: 将 cell 转成 Code 模式
# - **Esc + M**: 将 cell 转成 Markdown 模式
# - **Esc + Shift + K(up)**: 选上面的 cell
# - **Esc + Shift + J(down)**: 选下面的 cell
# - **Esc + A**: 在上面插入新的 cell
# - **Esc + B**: 在下面插入新的 cell
# - **Esc + F**：查找并替代
#
# ### 编辑模式
#
# - **Ctrl + ]**：缩进
# - **Ctrl + [**：取消缩进
# - **Ctrl + /**：注释/取消注释
# - **Shift + TAB**：提示框

# %%
aa = 10
aa
# Out:
# 10

# %% [markdown]
# ## <font color = 'red'>3. 在jupyter中查看安装列表 在前面加！号</font>

# %%
! pip list
# Out:
# Package                 Version
# ----------------------- -----------
# absl-py                 2.1.0
# affine                  2.4.0
# appnope                 0.1.4
# asttokens               3.0.0
# attrs                   25.1.0
# Bottleneck              1.4.2
# Brotli                  1.0.9
# certifi                 2025.1.31
# charset-normalizer      3.3.2
# click                   8.1.8
# click-plugins           1.1.1
# cligj                   0.7.2
# comm                    0.2.2
# contextily              1.6.2
# contourpy               1.3.1
# cycler                  0.11.0
# cykhash                 2.0.1
# Cython                  3.0.11
# debugpy                 1.8.11
# decorator               5.2.1
# et-xmlfile              1.1.0
# exceptiongroup          1.2.2
# executing               2.1.0
# filelock                3.13.1
# fonttools               4.55.3
# geographiclib           2.0
# geojson                 3.2.0
# geopandas               1.0.1
# ...

# %% [markdown]
# ## <font color = 'red'>4. 在jupyter中查看安装包的版本</font>

# %%
# # system
import sys
print('System: %s' %sys.version)
# numpy
import numpy
print('numpy: %s' % numpy.__version__)
# pandas
import pandas
print('pandas: %s' % pandas.__version__)
# scipy
import scipy
print('scipy: %s' % scipy.__version__)
# matplotlib
import matplotlib
print('matplotlib: %s' % matplotlib.__version__)
# seaborn
import seaborn
print('seaborn: %s' % seaborn.__version__)
# pyecharts
import pyecharts
print('pyecharts: %s' % pyecharts.__version__)
# scikit-learn
import sklearn
print('sklearn: %s' % sklearn.__version__)
# Out:
# System: 3.12.8 | packaged by Anaconda, Inc. | (main, Dec 11 2024, 10:37:40) [Clang 14.0.6 ]
# numpy: 2.2.1
# pandas: 2.2.3
# scipy: 1.15.1
# matplotlib: 3.10.0
# seaborn: 0.13.2
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 20
#      18 print('seaborn: %s' % seaborn.__version__)
#      19 # pyecharts
# ---> 20 import pyecharts
#      21 print('pyecharts: %s' % pyecharts.__version__)
#      22 # scikit-learn
#
# ModuleNotFoundError: No module named 'pyecharts'

# %%
import pyecharts
print('pyecharts: %s' % pyecharts.__version__)
# Out:
# pyecharts: 2.0.3

# %% [markdown]
# ## <font color = 'red'>5. Python可以做什么：获取股票数据、数据分析与可视化</font>

# %%
import numpy as np
import pandas as pd
import tushare as ts
pro = ts.pro_api('818670fa68bc204c217143cdb75efeae1986031841ff8ca2c6a855bd')
ts.set_token('818670fa68bc204c217143cdb75efeae1986031841ff8ca2c6a855bd')

# %%
# Tushare API
data = pro.daily(ts_code='600030.SH', start_date = '20100101', end_date='')

# %%
data
# Out:
#         ts_code trade_date   open   high    low  close  pre_close  change  \
# 0     600030.SH   20250402  26.40  26.61  26.35  26.54      26.44    0.10
# 1     600030.SH   20250401  26.52  26.66  26.39  26.44      26.52   -0.08
# 2     600030.SH   20250331  26.72  26.84  26.30  26.52      26.80   -0.28
# 3     600030.SH   20250328  26.98  27.03  26.73  26.80      26.90   -0.10
# 4     600030.SH   20250327  26.94  27.16  26.71  26.90      26.98   -0.08
# ...         ...        ...    ...    ...    ...    ...        ...     ...
# 3657  600030.SH   20100108  31.44  32.36  31.30  32.26      31.65    0.61
# 3658  600030.SH   20100107  32.42  32.88  31.40  31.65      32.44   -0.79
# 3659  600030.SH   20100106  33.00  33.15  32.40  32.44      32.82   -0.38
# 3660  600030.SH   20100105  31.55  33.10  30.81  32.82      31.29    1.53
# 3661  600030.SH   20100104  32.00  32.30  31.24  31.29      31.77   -0.48
#
#       pct_chg         vol       amount
# 0      0.3782   456718.67  1211260.842
# ...

# %%
data.head(20)    #DataFrame数据结构
# Out:
#       ts_code trade_date   open   high    low  close  pre_close  change  \
# 0   600030.SH   20250402  26.40  26.61  26.35  26.54      26.44    0.10
# 1   600030.SH   20250401  26.52  26.66  26.39  26.44      26.52   -0.08
# 2   600030.SH   20250331  26.72  26.84  26.30  26.52      26.80   -0.28
# 3   600030.SH   20250328  26.98  27.03  26.73  26.80      26.90   -0.10
# 4   600030.SH   20250327  26.94  27.16  26.71  26.90      26.98   -0.08
# 5   600030.SH   20250326  27.02  27.11  26.94  26.98      27.02   -0.04
# 6   600030.SH   20250325  27.20  27.22  27.00  27.02      27.19   -0.17
# 7   600030.SH   20250324  27.09  27.20  27.00  27.19      27.09    0.10
# 8   600030.SH   20250321  27.60  27.71  27.05  27.09      27.68   -0.59
# 9   600030.SH   20250320  27.93  27.95  27.61  27.68      27.93   -0.25
# 10  600030.SH   20250319  27.93  28.09  27.83  27.93      27.95   -0.02
# 11  600030.SH   20250318  27.96  28.11  27.84  27.95      27.86    0.09
# ...

# %%
data.tail( )    #DataFrame数据结构
# Out:
#         ts_code trade_date   open   high    low  close  pre_close  change  \
# 3657  600030.SH   20100108  31.44  32.36  31.30  32.26      31.65    0.61
# 3658  600030.SH   20100107  32.42  32.88  31.40  31.65      32.44   -0.79
# 3659  600030.SH   20100106  33.00  33.15  32.40  32.44      32.82   -0.38
# 3660  600030.SH   20100105  31.55  33.10  30.81  32.82      31.29    1.53
# 3661  600030.SH   20100104  32.00  32.30  31.24  31.29      31.77   -0.48
#
#       pct_chg         vol       amount
# 3657     1.93  1040929.92  3313809.660
# 3658    -2.44  1235592.34  3980014.778
# 3659    -1.16  1437889.30  4728323.923
# 3660     4.89  2093915.41  6750708.693
# 3661    -1.51  1106207.58  3510114.277

# %% [markdown]
# ## <font color = 'red'>6. 可以做笔记与注释：敲入公式</font>
#
#
# 资产的随机微分方程如下：
# <br/>
# <font color='blue'>
# \begin{equation}
# \frac{dS(t)}{S(t)} = rdt+\sigma dB(t)
# \end{equation}
# </font>
#
# 其中
#
# - $S(t)$ = 资产在时点 $t$ 的值
# - $r$ = 常数型瞬时利率
# - $\sigma$ = 常数型瞬时波动率
# - $B(t)$ = 布朗运动
#
# 根据 Black-Scholes 公式，欧式看涨期权的解析解为
#
# <br/>
# <font color='blue'>
# \begin{equation}
# \begin{aligned}
# \text{call} &= e^{-rT} \cdot E\left[ \left( S_T-K\right)^+\right] \\
# &= S_0\Phi(d_+) - e^{-rT}K\Phi(d_{-})
# \end{aligned}
# \end{equation}
# </font>
#
# 其中
#
# <br/>
# <font color='blue'>
# \begin{equation}
# d_{\pm} = \frac{1}{\sigma\sqrt{T}}\ln\left(\frac{S_0e^{rT}}{K}\right)\pm\frac{\sigma\sqrt{T}}{2}
# \end{equation}
# </font>

# %% [markdown]
# ## <font color = 'red'>8. 可以读入一个文档，进行分词统计</font>

# %%
# 根据文件名打开文件，分词
handle = open('Python.txt')
text = handle.read()
words = text.split()

# 计数词出现的个数
counts = dict()
for word in words:
    counts[word] = counts.get(word,0) + 1
    
# 找出出现次数最多的词
bigcount, bigword = None, None
for word, count in counts.items():
    if bigcount is None or count > bigcount:
        bigword = word
        bigcount = count
        
print( bigword, bigcount )
# Out:
# Python 4

# %% [markdown]
# ## <font color = 'red'>9. 可以画直方图</font>

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts
 
bar = Bar()
bar.add_xaxis(["数学", "物理", "化学", "英语"])
bar.add_yaxis("成绩", [70, 85, 95, 64])
bar.set_global_opts(title_opts=opts.TitleOpts(title="柱状图", subtitle="分数"))
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c72a0dd796b8412290722871ca1cf754" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c72a0dd796b8412290722871ca1cf754 = echarts.init(
#                     document.getElementById('c72a0dd796b8412290722871ca1cf754'), 'white', {renderer: 'canvas'});
#                 var option_c72a0dd796b8412290722871ca1cf754 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
from pyecharts.charts import Bar
from pyecharts import options as opts

# V1 版本以后开始支持链式调用，此处建议大家使用链式调用
bar = (
    Bar()  # 创建柱状图
    .add_xaxis(["衬衫", "毛衣", "领带", "裤子", "风衣", "高跟鞋", "袜子"])  # 增加横轴
    .add_yaxis("商家A", [114, 55, 27, 101, 125, 27, 105])  # 增加第一条纵轴
    .add_yaxis("商家B", [57, 134, 137, 129, 145, 60, 49])  # 增加第二条纵轴
    .set_global_opts(title_opts=opts.TitleOpts(title="某商场销售情况"))  # 通过全局配置项设置图片的标题
)
# 渲染图片
bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="c62f1674b3c544be832e5eba5146c643" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_c62f1674b3c544be832e5eba5146c643 = echarts.init(
#                     document.getElementById('c62f1674b3c544be832e5eba5146c643'), 'white', {renderer: 'canvas'});
#                 var option_c62f1674b3c544be832e5eba5146c643 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %% [markdown]
# ## <font color = 'red'>10. 可以读入网络图片</font>

# %%
from IPython.display import Image
Image(url= "http://img51.ddimg.cn/99999990102599841.jpg", 
      width=500, height=1000)
# Out:
# <img src="http://img51.ddimg.cn/99999990102599841.jpg" width="500" height="1000"/>

# %%
import os
print(os.getcwd())  # 显示当前路径
# Out:
# /Users/ncc1031a/Documents/VSCode/FinancialTech/1_Python_basics
